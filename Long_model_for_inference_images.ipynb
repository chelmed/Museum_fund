# %%
import numpy as np 
import pandas as pd 
import os
import gc
import random
import time
from PIL import ImageFile, Image

import tensorflow as tf
import efficientnet.tfkeras as efn
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array
import tensorflow.keras.models as M
from tensorflow.keras import backend as K
import tensorflow.keras.layers as L
from tensorflow.keras import optimizers
from tensorflow.keras.models import load_model
from tensorflow.keras import utils
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import LabelEncoder

# %%
import matplotlib
import sklearn
print("pandas version: ", pd.__version__)
print("numpy version: ", np.__version__)
print("sklearn version: ", sklearn.__version__)
print("matplotlib version: ", matplotlib.__version__)
print("tensorflow version: ", tf.__version__)
print("efficientnet version: 1.1.1")
# Out:
# pandas version:  1.2.2
# numpy version:  1.19.5
# sklearn version:  0.23.2
# matplotlib version:  3.3.2
# tensorflow version:  2.4.1
# efficientnet version: 1.1.1

# %% [markdown]
# ###### подробнее про библиотеку efficientnet: https://pypi.org/project/keras-efficientnets/

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true' #gpu
#Whether or not to load truncated image files
ImageFile.LOAD_TRUNCATED_IMAGES = True
#Image size exceeds not limit
Image.MAX_IMAGE_PIXELS = None

# %%
seed=42    
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# кастомная функция для f1
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
train = pd.read_csv('train_for_final_images_model_2.csv')

# %%
train['image_id']  = train['guid'] + '.jpg'

# %%
train.head()
# Out:
#                                    guid typology  \
# 0  a1030fb5-af65-4185-9ac4-d0f84f0c268e   прочие
# 1  2e5b0cdf-6668-4e10-a0a1-8b885f6ce61b   прочие
# 2  17dd91e9-a200-432e-8046-278e580f5f3e   прочие
# 3  c17896b3-302c-451a-aaae-18a184988155   прочие
# 4  ce7f88e5-586a-4a99-ac4c-6a8f1820ddc4   прочие
#
#                                    image_id
# 0  a1030fb5-af65-4185-9ac4-d0f84f0c268e.jpg
# 1  2e5b0cdf-6668-4e10-a0a1-8b885f6ce61b.jpg
# 2  17dd91e9-a200-432e-8046-278e580f5f3e.jpg
# 3  c17896b3-302c-451a-aaae-18a184988155.jpg
# 4  ce7f88e5-586a-4a99-ac4c-6a8f1820ddc4.jpg

# %%
train['typology'].value_counts()
# Out:
# фотографии и негативы                                18723
# предметы археологии                                  14834
# предметы нумизматики                                 14044
# предметы прикладного искусства, быта и этнографии    13087
# документы                                            12572
# предметы печатной продукции                          10208
# графика                                               6774
# редкие книги                                          3697
# предметы естественнонаучной коллекции                 2982
# оружие                                                2755
# скульптура                                            2422
# предметы минералогической коллекции                   2376
# предметы техники                                      2374
# живопись                                              2016
# прочие                                                1888
# Name: typology, dtype: int64

# %%
train, valid = train_test_split(train, test_size = 0.1, stratify=train['typology'], random_state=seed)

# %%
IMG_SIZE = 312
input_shape=(IMG_SIZE, IMG_SIZE, 3)
AUTO = tf.data.experimental.AUTOTUNE
batch_size = 8

# %%
datagen_train = ImageDataGenerator(rescale=1./(IMG_SIZE - 1), 
                                   zoom_range=[0.95,1.05],
                                   height_shift_range=0.05,
                                   width_shift_range=0.05,
                                   fill_mode='nearest',
                                   brightness_range=[0.95,1.05]
                                  )

# %%
datagen_test = ImageDataGenerator(rescale=1./(IMG_SIZE - 1))

# %%
def create_datagen_train(df):
    return datagen_train.flow_from_dataframe(
        dataframe=df,
        directory="images",
        x_col="image_id",
        y_col="typology",
        target_size=(IMG_SIZE, IMG_SIZE),
        color_mode="rgb",
        batch_size=batch_size,
        class_mode='categorical',
        #validation_split=0.15,
        shuffle=True, 
        seed=seed)

# %%
def create_datagen_validation(df):
    return datagen_test.flow_from_dataframe(
        dataframe=df,
        directory="images",
        x_col="image_id",
        y_col="typology",
        target_size=(IMG_SIZE, IMG_SIZE),
        color_mode="rgb",
        batch_size=batch_size,
        class_mode='categorical',
        #validation_split=0.15,
        shuffle=False,
        seed=seed)

# %% [markdown]
# Загружу общедоступные предобученные веса на Imagenet на архитектуре EfficientNetB6, на основе этой архитерктуры достроим нейронную сеть подробнее про архитектуру https://paperswithcode.com/paper/fixing-the-train-test-resolution-discrepancy-2

# %% [markdown]
# Сохраню веса (для случая недоступности интернета)

# %%
#base_model = efn.EfficientNetB6(weights="imagenet", include_top=False, input_shape=input_shape)
#base_model.save("EfficientNetB6.h5")

# %%
base_model = efn.EfficientNetB6(weights="EfficientNetB6.h5", include_top=False, input_shape=input_shape)
base_model.trainable = True

# %%
def architecture_NN():
    inp = L.Input(shape=input_shape)
    x = base_model(inp)
    x = L.GlobalAveragePooling2D()(x)
    out = L.Dense(15, activation = 'softmax', kernel_initializer='glorot_uniform')(x)
    model = tf.keras.models.Model(inputs = inp, outputs = out)
    return model

# %%
architecture_NN().summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 312, 312, 3)]     0
# _________________________________________________________________
# efficientnet-b6 (Functional) (None, 10, 10, 2304)      40960136
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 15)                34575
# =================================================================
# Total params: 40,994,711
# Trainable params: 40,770,279
# Non-trainable params: 224,432
# _________________________________________________________________

# %%
LR = 0.00009
num_epochs = 6
checkpoint = ModelCheckpoint(filepath='Models_images/long_models_for_inference/best_model.5', monitor=['val_loss'], verbose=1, mode='min')
es = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1, mode='min')
train_generator = create_datagen_train(train)
valid_generator = create_datagen_validation(valid)
model = architecture_NN()
model.compile(loss="categorical_crossentropy", optimizer=optimizers.Adam(LR), metrics=[f1_m])
# Out:
# Found 99676 validated image filenames belonging to 15 classes.
# Found 11076 validated image filenames belonging to 15 classes.

# %%
start_time = time.time()
history = model.fit(train_generator, 
                    validation_data=valid_generator,
                    callbacks=[checkpoint, es],
                    epochs = num_epochs)
model.save(f"Models_images/long_models_for_inference/model_final_predict_image_.h5")
print(f"hours: {(time.time()-start_time)/3600}")
# Out:
# Epoch 1/6
#  1830/12460 [===>..........................] - ETA: 1:34:48 - loss: 1.2656 - f1_m: 0.5153
# /home/eugene/anaconda3/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:791: UserWarning: Image appears to be a malformed MPO file, it will be interpreted as a base JPEG file
#   warnings.warn(
# 12460/12460 [==============================] - 7170s 574ms/step - loss: 0.7812 - f1_m: 0.7199 - val_loss: 0.3798 - val_f1_m: 0.8684
#
# Epoch 00001: saving model to Models_images/long_models_for_inference/best_model
# INFO:tensorflow:Assets written to: Models_images/long_models_for_inference/best_model/assets
# Epoch 2/6
#  3219/12460 [======>.......................] - ETA: 1:24:42 - loss: 0.3976 - f1_m: 0.8647
# /home/eugene/anaconda3/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:791: UserWarning: Image appears to be a malformed MPO file, it will be interpreted as a base JPEG file
#   warnings.warn(
# 12460/12460 [==============================] - 7096s 570ms/step - loss: 0.3925 - f1_m: 0.8651 - val_loss: 0.3166 - val_f1_m: 0.8935
#
# Epoch 00002: saving model to Models_images/long_models_for_inference/best_model
# INFO:tensorflow:Assets written to: Models_images/long_models_for_inference/best_model/assets
# Epoch 3/6
#   148/12460 [..............................] - ETA: 2:04:09 - loss: 0.2876 - f1_m: 0.8899
# /home/eugene/anaconda3/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:791: UserWarning: Image appears to be a malformed MPO file, it will be interpreted as a base JPEG file
#   warnings.warn(
# 12460/12460 [==============================] - 7120s 571ms/step - loss: 0.3081 - f1_m: 0.8910 - val_loss: 0.3316 - val_f1_m: 0.8976
#
# Epoch 00003: saving model to Models_images/long_models_for_inference/best_model
# INFO:tensorflow:Assets written to: Models_images/long_models_for_inference/best_model/assets
# Epoch 4/6
#  2445/12460 [====>.........................] - ETA: 1:31:43 - loss: 0.2588 - f1_m: 0.9070
# /home/eugene/anaconda3/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:791: UserWarning: Image appears to be a malformed MPO file, it will be interpreted as a base JPEG file
#   warnings.warn(
# 12460/12460 [==============================] - 7056s 566ms/step - loss: 0.2595 - f1_m: 0.9069 - val_loss: 0.3204 - val_f1_m: 0.8982
#
# Epoch 00004: saving model to Models_images/long_models_for_inference/best_model
# INFO:tensorflow:Assets written to: Models_images/long_models_for_inference/best_model/assets
# Epoch 5/6
#   320/12460 [..............................] - ETA: 1:47:10 - loss: 0.1902 - f1_m: 0.9269
# /home/eugene/anaconda3/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:791: UserWarning: Image appears to be a malformed MPO file, it will be interpreted as a base JPEG file
#   warnings.warn(
# 12460/12460 [==============================] - 6756s 542ms/step - loss: 0.2211 - f1_m: 0.9192 - val_loss: 0.3201 - val_f1_m: 0.9071
#
# Epoch 00005: saving model to Models_images/long_models_for_inference/best_model
# INFO:tensorflow:Assets written to: Models_images/long_models_for_inference/best_model/assets
# Restoring model weights from the end of the best epoch.
# Epoch 00005: early stopping
# hours: 9.849952221976386

# %%
len(history.model.weights)
# Out:
# 852

# %%
model.save(f"Models_images/long_models_for_inference/model_images.h5")

# %%
predict = model.predict(valid_generator)
# Out:
# /home/eugene/anaconda3/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:791: UserWarning: Image appears to be a malformed MPO file, it will be interpreted as a base JPEG file
#   warnings.warn(

# %%
import pickle
with open('Models_text/LabelEncoder.pickle', 'rb') as handle:
    le = pickle.load(handle)

# %%
valid['typology_predict'] = le.inverse_transform(np.argmax(predict, axis=1))

# %%
from sklearn.metrics import f1_score
f1_score(valid['typology'], valid['typology_predict'], average='macro')
# Out:
# 0.8618282719560516

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(valid['typology'], valid['typology_predict'])

# %%
cm_df = pd.DataFrame(cm,
                     index = le.classes_.tolist(), 
                     columns = le.classes_.tolist())

# %%
cm_df
# Out:
#                                                    графика  документы  \
# графика                                                552          0
# документы                                                1       1131
# живопись                                                22          0
# оружие                                                   0          0
# предметы археологии                                      0          0
# предметы естественнонаучной коллекции                    0          0
# предметы минералогической коллекции                      0          0
# предметы нумизматики                                     4          0
# предметы печатной продукции                             19        108
# предметы прикладного искусства, быта и этнографии        2          0
# предметы техники                                         1          0
# прочие                                                   1          0
# редкие книги                                             0         19
# скульптура                                               0          0
# фотографии и негативы                                   11          0
#
#                                                    живопись  оружие  \
# графика                                                  21       0
# документы                                                 0       0
# живопись                                                171       0
# оружие                                                    0     271
# предметы археологии                                       0       5
# предметы естественнонаучной коллекции                     0       1
# предметы минералогической коллекции                       0       0
# предметы нумизматики                                      0       0
# предметы печатной продукции                               0       0
# предметы прикладного искусства, быта и этнографии         2       9
# предметы техники                                          0       2
# прочие                                                    0       6
# редкие книги                                              0       0
# скульптура                                                0       0
# фотографии и негативы                                     1       0
#
#                                                    предметы археологии  \
# графика                                                              0
# документы                                                            0
# живопись                                                             0
# оружие                                                               0
# предметы археологии                                               1389
# предметы естественнонаучной коллекции                               23
# предметы минералогической коллекции                                 14
# предметы нумизматики                                                 2
# предметы печатной продукции                                          0
# предметы прикладного искусства, быта и этнографии                   18
# предметы техники                                                     0
# прочие                                                               0
# редкие книги                                                         0
# скульптура                                                           0
# фотографии и негативы                                                0
#
#                                                    предметы естественнонаучной коллекции  \
# графика                                                                                1
# документы                                                                              0
# живопись                                                                               0
# оружие                                                                                 0
# предметы археологии                                                                   16
# предметы естественнонаучной коллекции                                                250
# предметы минералогической коллекции                                                    0
# предметы нумизматики                                                                   3
# предметы печатной продукции                                                            0
# предметы прикладного искусства, быта и этнографии                                      5
# предметы техники                                                                       0
# прочие                                                                                 1
# редкие книги                                                                           0
# скульптура                                                                             0
# фотографии и негативы                                                                  0
#
#                                                    предметы минералогической коллекции  \
# графика                                                                              0
# документы                                                                            0
# живопись                                                                             0
# оружие                                                                               0
# предметы археологии                                                                 20
# предметы естественнонаучной коллекции                                               12
# предметы минералогической коллекции                                                222
# предметы нумизматики                                                                 0
# предметы печатной продукции                                                          0
# предметы прикладного искусства, быта и этнографии                                    0
# предметы техники                                                                     0
# прочие                                                                               0
# редкие книги                                                                         0
# скульптура                                                                           0
# фотографии и негативы                                                                0
#
#                                                    предметы нумизматики  \
# графика                                                               0
# документы                                                             0
# живопись                                                              0
# оружие                                                                0
# предметы археологии                                                   1
# предметы естественнонаучной коллекции                                 2
# предметы минералогической коллекции                                   0
# предметы нумизматики                                               1389
# предметы печатной продукции                                           4
# предметы прикладного искусства, быта и этнографии                    31
# предметы техники                                                      0
# прочие                                                                1
# редкие книги                                                          1
# скульптура                                                            0
# фотографии и негативы                                                 0
#
#                                                    предметы печатной продукции  \
# графика                                                                     82
# документы                                                                  111
# живопись                                                                     5
# оружие                                                                       0
# предметы археологии                                                          0
# предметы естественнонаучной коллекции                                        0
# предметы минералогической коллекции                                          0
# предметы нумизматики                                                         1
# предметы печатной продукции                                                726
# предметы прикладного искусства, быта и этнографии                            0
# предметы техники                                                             0
# прочие                                                                       6
# редкие книги                                                                61
# скульптура                                                                   0
# фотографии и негативы                                                       25
#
#                                                    предметы прикладного искусства, быта и этнографии  \
# графика                                                                                            1
# документы                                                                                          0
# живопись                                                                                           3
# оружие                                                                                             4
# предметы археологии                                                                               51
# предметы естественнонаучной коллекции                                                              9
# предметы минералогической коллекции                                                                0
# предметы нумизматики                                                                               5
# предметы печатной продукции                                                                        0
# предметы прикладного искусства, быта и этнографии                                               1164
# предметы техники                                                                                  41
# прочие                                                                                            53
# редкие книги                                                                                       1
# скульптура                                                                                         0
# фотографии и негативы                                                                              0
#
#                                                    предметы техники  прочие  \
# графика                                                           0       0
# документы                                                         0       5
# живопись                                                          0       0
# оружие                                                            1       0
# предметы археологии                                               0       0
# предметы естественнонаучной коллекции                             1       0
# предметы минералогической коллекции                               0       2
# предметы нумизматики                                              0       0
# предметы печатной продукции                                       0       3
# предметы прикладного искусства, быта и этнографии                32      21
# предметы техники                                                186       7
# прочие                                                           10     104
# редкие книги                                                      0       0
# скульптура                                                        0       0
# фотографии и негативы                                             1       0
#
#                                                    редкие книги  скульптура  \
# графика                                                       0           0
# документы                                                     9           0
# живопись                                                      0           0
# оружие                                                        0           0
# предметы археологии                                           0           2
# предметы естественнонаучной коллекции                         0           0
# предметы минералогической коллекции                           0           0
# предметы нумизматики                                          0           0
# предметы печатной продукции                                 104           0
# предметы прикладного искусства, быта и этнографии             0          25
# предметы техники                                              0           0
# прочие                                                        0           3
# редкие книги                                                288           0
# скульптура                                                    0         242
# фотографии и негативы                                         0           8
#
#                                                    фотографии и негативы
# графика                                                               20
# документы                                                              0
# живопись                                                               1
# оружие                                                                 0
# предметы археологии                                                    0
# предметы естественнонаучной коллекции                                  0
# предметы минералогической коллекции                                    0
# предметы нумизматики                                                   0
# предметы печатной продукции                                           57
# предметы прикладного искусства, быта и этнографии                      0
# предметы техники                                                       0
# прочие                                                                 4
# редкие книги                                                           0
# скульптура                                                             0
# фотографии и негативы                                               1826

# %%
import sklearn.metrics
for i in valid['typology'].unique():
    print(i)
    print(sklearn.metrics.accuracy_score(valid.query(f"typology=='{i}'")['typology'], valid.query(f"typology=='{i}'")['typology_predict']))
# Out:
# предметы печатной продукции
# 0.7110675808031341
# предметы техники
# 0.7848101265822784
# редкие книги
# 0.7783783783783784
# прочие
# 0.5502645502645502
# фотографии и негативы
# 0.9754273504273504
# оружие
# 0.9818840579710145
# документы
# 0.8997613365155132
# предметы археологии
# 0.9359838274932615
# предметы нумизматики
# 0.9893162393162394
# предметы прикладного искусства, быта и этнографии
# 0.8892284186401833
# графика
# 0.8153618906942393
# скульптура
# 1.0
# предметы естественнонаучной коллекции
# 0.8389261744966443
# предметы минералогической коллекции
# 0.9327731092436975
# живопись
# 0.8465346534653465

# %%
m = tf.keras.models.load_model(f"Models_images/long_models_for_inference/best_model/", custom_objects={'f1_m': f1_m})

# %%
predict = m.predict(valid_generator)
# Out:
# /home/eugene/anaconda3/lib/python3.8/site-packages/PIL/JpegImagePlugin.py:791: UserWarning: Image appears to be a malformed MPO file, it will be interpreted as a base JPEG file
#   warnings.warn(

# %%
valid['typology_predict'] = le.inverse_transform(np.argmax(predict, axis=1))

# %%
f1_score(valid['typology'], valid['typology_predict'], average='macro')
# Out:
# 0.8860664226623326

# %%
cm = confusion_matrix(valid['typology'], valid['typology_predict'])

# %%
cm_df = pd.DataFrame(cm,
                     index = le.classes_.tolist(), 
                     columns = le.classes_.tolist())

# %%
cm_df
# Out:
#                                                    графика  документы  \
# графика                                                574          0
# документы                                                1       1168
# живопись                                                16          0
# оружие                                                   0          0
# предметы археологии                                      0          0
# предметы естественнонаучной коллекции                    0          0
# предметы минералогической коллекции                      0          0
# предметы нумизматики                                     2          0
# предметы печатной продукции                             39        140
# предметы прикладного искусства, быта и этнографии        0          0
# предметы техники                                         0          2
# прочие                                                   0          0
# редкие книги                                             0         21
# скульптура                                               0          0
# фотографии и негативы                                   36          0
#
#                                                    живопись  оружие  \
# графика                                                  44       0
# документы                                                 0       0
# живопись                                                178       0
# оружие                                                    0     275
# предметы археологии                                       0       3
# предметы естественнонаучной коллекции                     0       2
# предметы минералогической коллекции                       0       0
# предметы нумизматики                                      0       1
# предметы печатной продукции                               1       0
# предметы прикладного искусства, быта и этнографии         1      17
# предметы техники                                          0       2
# прочие                                                    0       5
# редкие книги                                              0       0
# скульптура                                                0       0
# фотографии и негативы                                     3       0
#
#                                                    предметы археологии  \
# графика                                                              1
# документы                                                            0
# живопись                                                             0
# оружие                                                               0
# предметы археологии                                               1415
# предметы естественнонаучной коллекции                               21
# предметы минералогической коллекции                                  4
# предметы нумизматики                                                 0
# предметы печатной продукции                                          0
# предметы прикладного искусства, быта и этнографии                   32
# предметы техники                                                     0
# прочие                                                               0
# редкие книги                                                         0
# скульптура                                                           0
# фотографии и негативы                                                0
#
#                                                    предметы естественнонаучной коллекции  \
# графика                                                                                0
# документы                                                                              0
# живопись                                                                               0
# оружие                                                                                 0
# предметы археологии                                                                    8
# предметы естественнонаучной коллекции                                                244
# предметы минералогической коллекции                                                    0
# предметы нумизматики                                                                   0
# предметы печатной продукции                                                            0
# предметы прикладного искусства, быта и этнографии                                      3
# предметы техники                                                                       0
# прочие                                                                                 0
# редкие книги                                                                           0
# скульптура                                                                             0
# фотографии и негативы                                                                  0
#
#                                                    предметы минералогической коллекции  \
# графика                                                                              2
# документы                                                                            0
# живопись                                                                             0
# оружие                                                                               0
# предметы археологии                                                                 14
# предметы естественнонаучной коллекции                                               22
# предметы минералогической коллекции                                                234
# предметы нумизматики                                                                 0
# предметы печатной продукции                                                          0
# предметы прикладного искусства, быта и этнографии                                    1
# предметы техники                                                                     0
# прочие                                                                               0
# редкие книги                                                                         0
# скульптура                                                                           0
# фотографии и негативы                                                                0
#
#                                                    предметы нумизматики  \
# графика                                                               0
# документы                                                             0
# живопись                                                              0
# оружие                                                                0
# предметы археологии                                                   3
# предметы естественнонаучной коллекции                                 3
# предметы минералогической коллекции                                   0
# предметы нумизматики                                               1393
# предметы печатной продукции                                           1
# предметы прикладного искусства, быта и этнографии                    25
# предметы техники                                                      0
# прочие                                                                0
# редкие книги                                                          1
# скульптура                                                            0
# фотографии и негативы                                                 0
#
#                                                    предметы печатной продукции  \
# графика                                                                     42
# документы                                                                   76
# живопись                                                                     4
# оружие                                                                       0
# предметы археологии                                                          2
# предметы естественнонаучной коллекции                                        0
# предметы минералогической коллекции                                          0
# предметы нумизматики                                                         0
# предметы печатной продукции                                                704
# предметы прикладного искусства, быта и этнографии                            0
# предметы техники                                                             0
# прочие                                                                       2
# редкие книги                                                                52
# скульптура                                                                   0
# фотографии и негативы                                                       37
#
#                                                    предметы прикладного искусства, быта и этнографии  \
# графика                                                                                            4
# документы                                                                                          0
# живопись                                                                                           2
# оружие                                                                                             1
# предметы археологии                                                                               38
# предметы естественнонаучной коллекции                                                              6
# предметы минералогической коллекции                                                                0
# предметы нумизматики                                                                               5
# предметы печатной продукции                                                                        0
# предметы прикладного искусства, быта и этнографии                                               1161
# предметы техники                                                                                  10
# прочие                                                                                            19
# редкие книги                                                                                       1
# скульптура                                                                                         0
# фотографии и негативы                                                                              0
#
#                                                    предметы техники  прочие  \
# графика                                                           0       1
# документы                                                         0       5
# живопись                                                          0       1
# оружие                                                            0       0
# предметы археологии                                               0       1
# предметы естественнонаучной коллекции                             0       0
# предметы минералогической коллекции                               0       0
# предметы нумизматики                                              1       1
# предметы печатной продукции                                       0       3
# предметы прикладного искусства, быта и этнографии                36      21
# предметы техники                                                220       3
# прочие                                                            8     153
# редкие книги                                                      0       0
# скульптура                                                        0       0
# фотографии и негативы                                             1       2
#
#                                                    редкие книги  скульптура  \
# графика                                                       0           0
# документы                                                     6           0
# живопись                                                      0           1
# оружие                                                        0           0
# предметы археологии                                           0           0
# предметы естественнонаучной коллекции                         0           0
# предметы минералогической коллекции                           0           0
# предметы нумизматики                                          0           0
# предметы печатной продукции                                  92           0
# предметы прикладного искусства, быта и этнографии             2          10
# предметы техники                                              0           0
# прочие                                                        0           0
# редкие книги                                                295           0
# скульптура                                                    0         242
# фотографии и негативы                                         0           4
#
#                                                    фотографии и негативы
# графика                                                                9
# документы                                                              1
# живопись                                                               0
# оружие                                                                 0
# предметы археологии                                                    0
# предметы естественнонаучной коллекции                                  0
# предметы минералогической коллекции                                    0
# предметы нумизматики                                                   1
# предметы печатной продукции                                           41
# предметы прикладного искусства, быта и этнографии                      0
# предметы техники                                                       0
# прочие                                                                 2
# редкие книги                                                           0
# скульптура                                                             0
# фотографии и негативы                                               1789

# %%
import sklearn.metrics
for i in valid['typology'].unique():
    print(i)
    print(sklearn.metrics.accuracy_score(valid.query(f"typology=='{i}'")['typology'], valid.query(f"typology=='{i}'")['typology_predict']))
# Out:
# предметы печатной продукции
# 0.6895200783545543
# предметы техники
# 0.9282700421940928
# редкие книги
# 0.7972972972972973
# прочие
# 0.8095238095238095
# фотографии и негативы
# 0.9556623931623932
# оружие
# 0.9963768115942029
# документы
# 0.9291964996022275
# предметы археологии
# 0.9535040431266847
# предметы нумизматики
# 0.9921652421652422
# предметы прикладного искусства, быта и этнографии
# 0.8869365928189458
# графика
# 0.8478581979320532
# скульптура
# 1.0
# предметы естественнонаучной коллекции
# 0.8187919463087249
# предметы минералогической коллекции
# 0.9831932773109243
# живопись
# 0.8811881188118812

# %%
m.save(f"Models_images/long_models_for_inference/model_images_2.h5")

# %%
m = tf.keras.models.load_model(f"Models_images/long_models_for_inference/model_images_2.h5", custom_objects={'f1_m': f1_m})
